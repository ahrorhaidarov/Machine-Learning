# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
def load_data(file_path):
    return pd.read_csv(file_path)

df = load_data('dataset.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.0           5.2          2.3  virginica
# 145           6.3          2.5           5.0          1.9  virginica
# 146           6.5          3.0           5.2          2.0  virginica
# 147           6.2          3.4           5.4          2.3  virginica
# 148           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
df = df[['petal_length', 'petal_width']]
df
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 144           5.2          2.3
# 145           5.0          1.9
# 146           5.2          2.0
# 147           5.4          2.3
# 148           5.1          1.8
#
# [149 rows x 2 columns]

# %%
X = df.petal_length
y = df.petal_width

# %%
plt.scatter(X, y)
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
X_train
# Out:
# 93     4.2
# 141    5.1
# 4      1.4
# 42     1.6
# 100    5.1
#       ...
# 118    5.0
# 61     4.0
# 143    5.7
# 62     4.7
# 132    5.1
# Name: petal_length, Length: 119, dtype: float64

# %%
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
m = model.coef_
m
# Out:
# array([0.41514697])

# %%
c = model.intercept_
c
# Out:
# -0.3743527360106782

# %% [markdown]
# # Formula of Linear Regression
# # y = mX + c

# %%
# First way
y_pred_train = m * X_train + c
y_pred_train
# Out:
# array([[1.36926454],
#        [1.74289682],
#        [0.20685302],
#        [0.28988242],
#        [1.74289682],
#        [1.61835272],
#        [1.74289682],
#        [0.41442651],
#        [0.16533833],
#        [0.20685302],
#        [0.20685302],
#        [0.24836772],
#        [0.28988242],
#        [1.61835272],
#        [1.61835272],
#        [0.24836772],
#        [0.20685302],
#        [2.49016136],
#        [1.32774985],
#        [0.20685302],
#        [0.08230893],
#        [1.24472045],
#        [1.20320575],
#        [1.9089556 ],
#        [1.36926454],
#        [1.57683803],
#        [1.49380863],
#        [2.40713197],
#        [2.0334997 ],
#        [2.11652909],
#        [1.49380863],
#        [0.33139711],
#        [1.9089556 ],
#        [0.99563227],
#        [1.82592621],
#        [1.65986742],
#        [1.07866166],
#        [1.9504703 ],
#        [0.28988242],
#        [1.9504703 ],
#        [1.12017636],
#        [1.57683803],
#        [0.20685302],
#        [1.9504703 ],
#        [1.49380863],
#        [1.65986742],
#        [1.16169106],
#        [1.24472045],
#        [0.12382363],
#        [0.28988242],
#        [1.53532333],
#        [0.20685302],
#        [0.16533833],
#        [1.70138212],
#        [1.86744091],
#        [0.16533833],
#        [1.86744091],
#        [1.65986742],
#        [1.36926454],
#        [1.65986742],
#        [1.74289682],
#        [1.32774985],
#        [0.16533833],
#        [0.87108818],
#        [0.24836772],
#        [0.33139711],
#        [1.45229394],
#        [1.49380863],
#        [1.78441151],
#        [1.70138212],
#        [1.53532333],
#        [0.41442651],
#        [2.15804379],
#        [0.20685302],
#        [0.33139711],
#        [1.41077924],
#        [1.53532333],
#        [0.33139711],
#        [0.16533833],
#        [0.24836772],
#        [2.0334997 ],
#        [2.36561727],
#        [2.07501439],
#        [0.24836772],
#        [1.32774985],
#        [2.0334997 ],
#        [0.99563227],
#        [0.24836772],
#        [1.57683803],
#        [1.28623515],
#        [1.45229394],
#        [1.9504703 ],
#        [2.24107318],
#        [2.15804379],
#        [1.36926454],
#        [0.28988242],
#        [0.20685302],
#        [0.24836772],
#        [0.24836772],
#        [1.49380863],
#        [1.74289682],
#        [0.24836772],
#        [0.20685302],
#        [0.20685302],
#        [1.9504703 ],
#        [0.28988242],
#        [1.49380863],
#        [1.9504703 ],
#        [1.28623515],
#        [0.24836772],
#        [2.15804379],
#        [1.45229394],
#        [1.74289682],
#        [1.9089556 ],
#        [1.70138212],
#        [1.28623515],
#        [1.991985  ],
#        [1.57683803],
#        [1.74289682]])

# %%
# Second way
y_pred_train1 = model.predict(X_train)
y_pred_train1
# Out:
# array([1.36926454, 1.74289682, 0.20685302, 0.28988242, 1.74289682,
#        1.61835272, 1.74289682, 0.41442651, 0.16533833, 0.20685302,
#        0.20685302, 0.24836772, 0.28988242, 1.61835272, 1.61835272,
#        0.24836772, 0.20685302, 2.49016136, 1.32774985, 0.20685302,
#        0.08230893, 1.24472045, 1.20320575, 1.9089556 , 1.36926454,
#        1.57683803, 1.49380863, 2.40713197, 2.0334997 , 2.11652909,
#        1.49380863, 0.33139711, 1.9089556 , 0.99563227, 1.82592621,
#        1.65986742, 1.07866166, 1.9504703 , 0.28988242, 1.9504703 ,
#        1.12017636, 1.57683803, 0.20685302, 1.9504703 , 1.49380863,
#        1.65986742, 1.16169106, 1.24472045, 0.12382363, 0.28988242,
#        1.53532333, 0.20685302, 0.16533833, 1.70138212, 1.86744091,
#        0.16533833, 1.86744091, 1.65986742, 1.36926454, 1.65986742,
#        1.74289682, 1.32774985, 0.16533833, 0.87108818, 0.24836772,
#        0.33139711, 1.45229394, 1.49380863, 1.78441151, 1.70138212,
#        1.53532333, 0.41442651, 2.15804379, 0.20685302, 0.33139711,
#        1.41077924, 1.53532333, 0.33139711, 0.16533833, 0.24836772,
#        2.0334997 , 2.36561727, 2.07501439, 0.24836772, 1.32774985,
#        2.0334997 , 0.99563227, 0.24836772, 1.57683803, 1.28623515,
#        1.45229394, 1.9504703 , 2.24107318, 2.15804379, 1.36926454,
#        0.28988242, 0.20685302, 0.24836772, 0.24836772, 1.49380863,
#        1.74289682, 0.24836772, 0.20685302, 0.20685302, 1.9504703 ,
#        0.28988242, 1.49380863, 1.9504703 , 1.28623515, 0.24836772,
#        2.15804379, 1.45229394, 1.74289682, 1.9089556 , 1.70138212,
#        1.28623515, 1.991985  , 1.57683803, 1.74289682])

# %%
plt.scatter(X_train, y_train)
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.scatter(X_train, y_pred_train1, color='red')
plt.show()

# %%
plt.scatter(X_train, y_train)
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.plot(X_train, y_pred_train1, color='red')
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.show()

# %%
y_pred_test = model.predict(X_test)
y_pred_test
# Out:
# array([2.11652909, 0.16533833, 1.07866166, 1.41077924, 1.991985  ,
#        1.24472045, 1.49380863, 0.12382363, 1.61835272, 2.07501439,
#        0.04079424, 0.24836772, 0.24836772, 1.28623515, 2.40713197,
#        1.49380863, 1.57683803, 2.28258788, 1.82592621, 1.28623515,
#        1.70138212, 1.45229394, 0.24836772, 0.24836772, 0.28988242,
#        1.74289682, 1.991985  , 1.78441151, 0.16533833, 1.65986742])

# %%
plt.scatter(X_test, y_test)
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.plot(X_test, y_pred_test, color='red')
plt.show()
